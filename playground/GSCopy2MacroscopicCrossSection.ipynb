# %%
#we may need some code in the ../python directory and/or matplotlib styles
import sys
sys.path.append('../python/')

#matplotlib for plotting
import matplotlib as mpl
from matplotlib import pyplot as plt
plt.style.use('../mplstyles/stylelib/standard.mplstyle')

import numpy as np

# %%
#Calculations for number density and other values
#Want microscopic cross section s where 
s=8.264e-24 #Elastic cross section of lead 209 at 10keV in cm^2
print(s)
rho=11.34 #in g/cm^3
m=3.469e-22 #in g
n=rho/m
print(n)
# Out:
# 8.264e-24
# 3.2689535889305275e+22

# %%
sigma=n*s
print(sigma)
# Out:
# 0.2701463245892188

# %%
a = np.random.exponential(scale=sigma, size=1000)
print(a)
# Out:
# [1.20962437e-01 2.12137900e-02 2.95124179e-01 2.95423677e-01
#  1.13098873e-01 3.65052751e-01 8.36735315e-02 5.43841891e-01
#  1.61384043e-01 8.84153070e-02 5.87477929e-01 1.82505375e-01
#  2.28977859e-01 8.30013468e-01 8.37587353e-02 2.78072294e-01
#  5.00489187e-02 2.35290372e-01 3.86960534e-02 7.98526876e-01
#  3.88310504e-01 6.00168543e-01 3.27867000e-01 1.29777541e-02
#  4.54929603e-02 5.89642344e-01 3.08397945e-01 6.47989395e-01
#  2.52043321e-02 3.63547961e-01 3.51223348e-01 6.10226577e-03
#  1.43550036e-01 2.14484595e-01 4.69110767e-02 1.95705308e-01
#  3.78860100e-01 6.66685321e-02 1.09656313e+00 7.17988263e-01
#  3.38046045e-01 3.84457269e-01 2.93114157e-01 5.68036394e-02
#  1.77905915e-01 2.13022113e-01 9.40290880e-02 1.67701593e-01
#  2.84239334e-02 1.26882293e-01 8.47887765e-01 1.05965727e-01
#  1.10577671e-01 1.14649879e-01 6.87813634e-02 1.80064478e-01
#  3.19633156e-01 2.12547539e-02 5.26319510e-01 5.62645737e-01
#  1.29453169e-01 8.42160601e-01 2.69647394e-01 5.83215884e-01
#  1.81855360e-01 9.51533581e-02 1.13476567e+00 6.93256115e-01
#  2.17950076e-02 4.40069257e-01 3.10320976e-01 3.17224656e-01
#  1.45543832e-01 7.12445675e-02 1.80631627e-01 2.99448417e-01
#  7.49543766e-01 1.28174159e-01 4.01655206e-03 3.76058516e-01
#  5.45728010e-01 1.85457666e-02 1.86297307e-01 1.73718811e-01
#  2.87986424e-01 4.84454247e-01 2.71583806e-01 6.08154354e-01
#  4.59453425e-01 1.49386422e-02 6.12057583e-02 5.24584046e-02
#  7.74366889e-02 1.75708722e-01 5.67898961e-02 5.21519322e-01
#  3.38761074e-01 1.61993437e-01 5.30519833e-02 1.07702379e-01
#  5.00609449e-02 5.44530303e-02 3.39673265e-01 2.54370318e-01
#  2.42304651e-01 8.89097584e-02 1.47828577e-01 4.79869344e-01
#  6.60873025e-02 2.85913096e-01 5.42194647e-01 1.98323330e-01
#  7.73805084e-03 6.81003166e-01 3.02972570e-01 1.49321229e-01
#  1.64325625e-01 7.72599816e-02 2.71639099e-01 1.21262435e-01
#  4.40574836e-01 9.29346042e-01 4.95269218e-02 8.01840436e-01
#  1.42411908e-01 3.58303639e-01 1.73555054e-01 4.37966762e-02
#  2.63030967e-01 1.10885213e+00 5.62941252e-01 9.88756019e-02
#  1.86114263e-01 8.95704221e-02 2.31766385e-01 1.33492508e-01
#  2.88340598e-02 7.51053321e-02 2.96151649e-02 5.39758845e-01
#  1.56455949e+00 8.60946922e-01 5.52367159e-02 2.19470979e-01
#  4.93374040e-01 5.35363274e-01 1.20425757e-01 4.08823308e-01
#  4.85708725e-02 1.74162637e-02 3.99379149e-01 3.11205020e-02
#  5.31788382e-01 4.03054348e-01 3.96624786e-02 5.00324883e-01
#  1.57085210e-02 3.53233353e-01 7.36789348e-01 9.99009229e-02
#  2.70680679e-02 2.96308004e-02 5.61537587e-02 5.25514001e-02
#  3.64301402e-01 3.23085615e-02 3.52622255e-02 3.44804403e-01
#  1.58936460e-01 6.74557829e-01 5.10523934e-01 1.88819742e-01
#  6.80803591e-04 2.58205694e-01 1.38721501e-01 4.99859951e-01
#  2.60849665e-01 2.53549461e-01 7.42052723e-01 1.71427021e-01
#  3.95286353e-02 6.16348360e-01 4.64452373e-01 1.43248396e-01
#  2.08557178e-01 1.79022002e-01 1.81102555e-02 9.97619636e-02
#  8.05635467e-02 1.01341036e-01 3.33119450e-02 5.37738730e-02
#  7.48966458e-02 2.03188952e-01 5.74706509e-02 1.54982660e-01
#  1.68683675e-01 7.08134049e-01 4.59429175e-02 2.01363410e-03
#  6.16058018e-02 2.17039338e-01 1.92055242e-01 9.85920840e-03
#  7.48760009e-01 3.26538699e-01 4.52369873e-01 3.09833476e-01
#  1.50664167e-01 6.58456984e-02 1.02886794e-02 1.07217441e+00
#  9.56937740e-03 8.22644794e-01 1.34469929e-01 7.04479406e-01
#  1.23132230e-05 1.77579757e-01 1.35878762e-01 3.79650749e-01
#  5.30320854e-01 1.03019858e+00 1.50323461e-01 3.32110815e-01
#  2.26540480e-01 3.72310931e-01 5.46206546e-01 2.50872907e-02
#  5.45956474e-01 7.77810838e-02 3.26498202e-01 1.38838673e-02
#  1.81419047e-01 2.47584362e-01 5.22820256e-03 9.77135196e-01
#  3.45179957e-02 7.51900661e-01 1.17019252e-02 3.99637535e-01
#  6.16743938e-02 1.86745982e-01 1.23694340e-01 2.23724663e-01
#  8.15942508e-03 4.28132445e-01 1.68454389e-01 6.66975296e-02
#  2.38782702e-01 2.71631797e-01 3.02957458e-01 4.83234315e-02
#  5.26698454e-01 2.17420607e-01 1.08069130e-01 2.03532599e-01
#  3.09259250e-01 2.31971372e-01 1.52959120e-01 7.70140630e-01
#  3.98280482e-02 1.36231793e-01 8.61197868e-02 1.48121555e-01
#  3.51906578e-01 1.42335556e-01 5.63847415e-01 2.89371540e-01
#  1.60029562e-01 8.19262510e-02 9.19013771e-02 2.20866573e-01
#  3.58634412e-01 5.62954232e-01 4.46203333e-02 8.20661747e-02
#  2.34278583e-01 4.75101130e-01 8.67253878e-02 2.46797488e-01
#  4.16039062e-01 1.42302027e-01 1.00685956e-02 1.86009209e-01
#  3.67339264e-01 1.88878924e+00 9.26709096e-01 1.13234446e-01
#  1.14385116e-01 2.95280396e-01 8.63541882e-01 2.48096597e-02
#  1.38534187e-01 5.73703846e-02 3.83220541e-01 6.27062717e-02
#  3.07200897e-01 6.47785943e-03 1.99612057e-01 5.77011978e-01
#  4.44704316e-01 3.17303183e-01 1.09979955e+00 1.43660263e-01
#  1.32796529e-01 1.29968880e-01 4.98997279e-01 7.09090836e-02
#  1.11841533e-01 2.94225315e-01 5.28750003e-01 1.75864682e-01
#  3.06505491e-02 8.31253084e-02 3.35462301e-01 3.17722311e-01
#  1.10562586e-01 2.50965351e-01 6.40651615e-01 7.31022110e-02
#  7.05268767e-02 1.18004951e-01 6.28750056e-01 2.48519723e-03
#  8.16010965e-02 1.28867184e-01 8.36704492e-01 7.21052657e-01
#  1.39148075e-01 1.51086195e-02 1.52529780e-01 7.57662147e-01
#  8.84396567e-02 4.30540212e-01 3.38598616e-01 6.33129996e-01
#  7.44242830e-01 5.64864111e-02 2.12060618e-01 2.26295080e-02
#  5.17552237e-02 6.26422183e-01 3.93070455e-01 1.06102643e-01
#  6.50456640e-01 5.63695049e-01 1.07257909e+00 6.64099159e-02
#  4.44797794e-01 2.88807043e-01 3.47360306e-01 4.45346258e-02
#  1.52986553e-01 5.04998996e-01 1.57218555e-01 1.71845945e-02
#  8.75070716e-01 9.25260314e-01 9.43553173e-03 4.34905666e-01
#  2.16618675e-01 6.80232444e-02 2.00837842e-01 1.33233661e-01
#  1.08311826e-01 6.17685478e-01 1.36418655e-01 2.89317845e-01
#  3.99301580e-02 1.81490256e-02 1.37030516e-01 1.19616033e-01
#  2.56317290e-02 3.83051329e-01 8.66292015e-01 2.55148266e-02
#  5.56621779e-02 4.73763565e-01 2.64475283e-01 1.09341688e+00
#  7.14076155e-02 1.69403607e-01 9.40295557e-02 2.55322586e-01
#  1.05418715e-01 1.57348388e-01 5.02942089e-01 5.78458040e-02
#  3.03659003e-01 7.22532631e-03 2.15595674e-01 2.05534932e-02
#  2.28383444e-01 1.29348198e-01 5.61330835e-02 3.97813875e-02
#  7.62055913e-02 4.80933902e-02 5.30216073e-02 7.82608807e-02
#  8.69658585e-01 1.78824770e-01 6.41511400e-01 4.58854260e-01
#  5.71227111e-02 9.68639202e-02 1.58312689e-01 1.14042543e+00
#  2.51605184e-01 1.41731306e-01 4.67584368e-01 5.09847815e-01
#  1.27340164e-01 3.66722358e-01 3.03981350e-01 4.09582580e-01
#  8.56807758e-03 4.85952097e-01 3.04722057e-01 8.65726541e-02
#  1.17107696e-01 6.61619125e-01 1.43595095e-01 1.78665740e-01
#  8.57989087e-02 1.01559360e+00 3.17119163e-03 3.72971627e-01
#  9.31126095e-01 7.22409643e-01 9.92203094e-01 1.51791942e-01
#  1.00980757e-01 1.13521878e-02 1.13986731e-01 1.21945940e-01
#  4.93846991e-01 6.73084888e-01 1.75402255e-01 1.69358645e-01
#  1.85382129e-01 1.04381671e-01 4.19998462e-01 6.00932790e-02
#  4.38675441e-02 4.46786709e-01 3.64471069e-01 3.65692460e-01
#  2.82845743e-01 1.47018535e-01 1.72388388e-01 2.10306168e-01
#  2.98960312e-02 1.61354290e-01 3.25111299e-01 1.01369555e-02
#  9.94879325e-02 2.53371597e-01 2.84272732e-01 9.94581489e-02
#  2.80641956e-01 7.05452363e-02 4.54514812e-01 3.93416280e-03
#  9.43055912e-02 1.08342621e-01 3.32362766e-02 2.08858003e-02
#  6.05739534e-01 5.28286846e-04 2.27592062e-01 6.24162535e-01
#  5.59222201e-01 3.47783251e-02 3.62705016e-02 5.04331985e-01
#  3.51312595e-02 1.88916026e-01 1.79067316e-01 1.93671774e-01
#  5.52932994e-01 1.43593642e-01 3.14417641e-01 2.98355673e-03
#  2.43380048e-01 4.84477121e-02 1.90918962e-01 4.90349176e-02
#  7.31366155e-02 1.99512193e-01 7.96747609e-01 1.39966116e+00
#  1.57115989e-01 2.33401131e-01 1.14663869e-01 5.57827473e-01
#  3.17694152e-01 2.50477774e-01 1.90524178e-01 1.04684864e-01
#  2.67511236e-01 1.71766148e-01 3.58124530e-01 8.07445548e-02
#  2.18492401e-01 2.35751482e-01 8.96396458e-02 4.71339677e-02
#  8.06191091e-02 1.33596214e-02 1.13981403e-01 2.20699308e-01
#  2.37588150e-01 1.17283398e-01 7.35076693e-02 3.28876535e-02
#  5.35172827e-04 6.56554489e-02 1.04682994e-01 3.93390127e-03
#  1.71402538e-01 5.33602404e-02 2.88749119e-01 2.14048782e-01
#  2.44210051e-01 5.72237198e-03 4.01199082e-01 1.81502170e-01
#  3.02108899e-01 1.34741251e-01 6.02374838e-03 7.33990758e-02
#  1.62392835e-01 4.73143821e-01 3.60324759e-02 7.06197659e-02
#  1.79822152e-01 1.58553476e-01 2.83076805e-01 3.31927628e-01
#  1.50404552e-02 9.02999340e-02 2.50040740e-01 6.89843756e-01
#  9.30658572e-01 2.82235834e-01 5.45352953e-01 6.44812247e-01
#  3.37341685e-01 5.74295656e-01 4.18425824e-02 2.67038722e-01
#  2.34786845e-02 1.04434830e-02 3.27297428e-01 3.99716425e-01
#  4.06563436e-01 4.29889955e-01 3.16349024e-01 1.57340720e-01
#  2.55651749e-03 3.32477427e-01 1.28895650e+00 1.37076885e+00
#  4.56544231e-02 8.92713564e-02 9.99853954e-02 1.93979906e-01
#  6.25518587e-02 6.46416817e-02 4.54311465e-01 1.16943165e-01
#  5.06851704e-02 1.47926826e-01 1.91198684e-01 2.18551304e-01
#  6.39274369e-01 2.54675539e-01 7.71083541e-02 6.26935301e-02
#  4.12863823e-01 3.72017148e-01 1.66227858e-01 7.13435578e-02
#  5.47092448e-01 5.59091866e-02 1.41086610e-03 5.53094155e-01
#  4.09333269e-02 1.80308100e-02 2.89534320e-01 2.43123218e-01
#  2.78728304e-01 1.15694341e-01 2.06740747e-01 4.96280925e-01
#  2.21589308e-01 5.89573946e-01 1.58592672e-01 6.78138641e-01
#  7.37899546e-01 4.88855478e-01 1.32398815e-01 1.25054227e-02
#  1.97185132e-01 3.54081713e-02 2.29967582e-01 8.68418151e-02
#  6.73323834e-02 2.34051604e-01 2.45923583e-01 1.10656487e+00
#  4.04394530e-01 5.43035287e-01 1.22286066e-02 1.17133553e-01
#  2.62014819e-01 2.74648633e-01 8.76894436e-02 5.97566950e-01
#  1.48062673e-01 1.82303086e-01 2.45383421e-01 1.52012881e-01
#  1.39510078e-01 4.60057691e-01 1.94110364e-01 1.18635385e-01
#  1.41201033e-02 5.91435880e-02 2.03667339e-01 1.66578987e-01
#  3.35719024e-01 3.48888544e-01 1.66170175e-01 1.39207517e-01
#  4.91651408e-01 5.29829823e-01 6.51782226e-03 2.42176893e-01
#  2.55698160e-01 1.20443464e-01 1.12925623e-01 7.56930119e-02
#  5.29138820e-02 1.51145178e-01 3.14834961e-02 3.41896464e-01
#  6.28611914e-01 1.96405613e-01 3.46299015e-02 3.78051204e-02
#  6.42079116e-01 5.08809708e-02 5.62055296e-02 2.45145811e-01
#  3.90917043e-01 7.54636947e-02 7.26945456e-01 1.58343966e-04
#  7.88707979e-01 7.82092569e-01 1.57760878e-01 1.58699943e-02
#  1.02105444e-01 4.72945531e-01 2.92309680e-01 2.65615051e-01
#  2.03283264e-01 1.82572427e-02 9.46679995e-02 5.37818547e-01
#  1.23457102e-01 1.00956992e-02 5.76818358e-02 5.30827042e-01
#  4.37553792e-01 7.32448179e-01 1.38294346e-01 1.28429423e-02
#  2.60525660e-01 1.12661848e-02 8.78199357e-02 2.46835283e-02
#  6.32118514e-03 8.91036737e-02 5.61096303e-01 4.50563148e-03
#  1.00042687e-01 1.93849723e-01 5.06551187e-03 5.52924095e-01
#  6.24518740e-02 5.09138188e-01 7.35714462e-02 4.24447816e-02
#  1.14267631e-01 2.60844445e-02 5.17083138e-01 9.37994675e-01
#  2.62777534e-01 2.81834881e-01 9.42596710e-01 4.32883743e-01
#  8.47020683e-02 7.25612839e-01 4.08598442e-01 1.56537006e-01
#  1.91477896e-01 1.62252005e-01 9.21886731e-02 2.12998565e-01
#  3.98140030e-02 1.50006362e-01 1.14659812e-01 1.53446222e-01
#  6.58148175e-02 1.28103204e-01 2.97239760e-01 3.04726756e-01
#  1.10452597e+00 7.23846828e-01 1.62060964e-01 3.14876308e-01
#  1.87698434e-01 9.50498632e-02 3.58355282e-01 5.61727815e-02
#  4.27098284e-01 1.63664515e-01 3.58550750e-01 5.55582327e-01
#  7.47163928e-03 5.18404864e-01 1.38011140e-01 1.56854235e-01
#  7.35134109e-01 5.38985834e-01 3.60310099e-02 1.45566008e-01
#  6.30762928e-02 1.21614237e-01 8.25426166e-02 1.33373867e-02
#  1.67449567e-01 2.02004439e-01 6.58053469e-01 8.84037910e-01
#  4.66406412e-02 6.67965442e-01 6.34816500e-02 4.72873214e-01
#  1.34774914e-01 3.13549178e-01 1.47538244e-01 1.53639058e-01
#  3.12814942e-01 4.61687994e-01 1.22352544e-01 2.96076486e-01
#  3.60988674e-01 1.97815122e-01 5.13119849e-02 5.64574048e-02
#  4.77069499e-01 1.76088648e-01 2.65964942e-02 6.15225851e-02
#  4.10045725e-02 6.68629396e-02 2.42052042e-01 6.50732906e-02
#  1.55245714e-01 3.69059413e-01 3.14724049e-01 1.42980797e-01
#  1.40543950e-01 5.21341559e-03 6.46673440e-02 4.79726447e-01
#  1.86746778e-01 2.26232200e-02 2.15359737e-01 9.47732085e-02
#  2.76126114e-01 1.30077291e-01 2.26032455e-01 1.17613509e-02
#  5.96457175e-02 4.29658727e-01 8.21314632e-01 2.23902836e-01
#  4.12735077e-01 1.08451048e-02 1.51157763e-01 4.75631038e-02
#  1.00101263e-02 2.02299936e-01 2.07207492e-01 3.14996984e-03
#  2.31315844e-01 1.04712887e-01 6.15343111e-02 9.12671289e-01
#  4.42819136e-03 9.15961161e-02 8.82738148e-01 6.57273707e-02
#  6.08992950e-02 9.13341205e-02 1.84448789e-01 6.97174226e-01
#  1.18195086e-01 1.31991008e-01 4.76399545e-01 1.74024284e-01
#  1.98664664e-01 4.61305832e-01 8.28468449e-02 2.69473972e-02
#  1.35766645e-01 5.45284415e-01 1.85227165e-01 3.44107860e-02
#  4.82057428e-01 3.46615125e-02 2.52251569e-01 1.54080050e-01
#  7.16484114e-01 4.88634961e-01 1.09169094e-01 1.07723119e-01
#  2.85254972e-01 1.61350440e-01 8.06437857e-01 1.01315199e-01
#  8.21967288e-03 5.01198782e-01 2.53954444e-01 1.18877156e-01
#  1.03894872e-01 1.65354230e-01 2.20176981e-01 8.70302748e-01
#  2.76671306e-01 4.17691837e-02 1.41254974e-01 5.86411471e-02
#  3.22478290e-01 3.41293125e-02 1.39226103e-01 2.06087762e-01
#  5.45688521e-01 1.62528748e-02 2.36692144e-01 2.30731119e-01
#  3.15002477e-01 8.50498506e-02 3.71849993e-01 1.95819741e-01
#  1.71010420e-01 1.44405271e-01 3.84798548e-02 6.33781855e-01
#  2.26352329e-02 3.02729607e-02 1.27298973e+00 8.86113331e-02
#  1.30245900e-01 2.12859457e-01 2.54229616e-01 4.21064456e-02
#  9.57529678e-03 1.95050874e-01 9.55695908e-01 2.09411233e-01
#  1.16482188e+00 2.08420673e-01 3.07797665e-01 1.63997424e-01
#  7.58850615e-02 7.77649186e-02 3.55837109e-03 1.54369227e-03
#  5.42781356e-02 2.73840238e-01 4.11215849e-01 4.26760313e-01
#  1.56509946e+00 9.49257894e-02 1.24512253e-01 1.90455698e-01
#  6.60211388e-02 2.33534671e-01 2.47288196e-01 1.87702470e-01
#  3.83916867e-02 4.27143311e-01 1.66812704e-01 1.50049332e+00
#  2.98782401e-02 1.81578243e-01 4.73059658e-02 2.36065027e-01
#  4.33500469e-01 9.20412669e-02 1.81762117e-01 4.22188132e-01
#  3.55678690e-01 1.23210304e-01 1.69125263e-03 9.81098179e-01
#  2.03367524e-02 6.15609083e-02 9.18198146e-03 6.71527433e-01
#  4.15350201e-01 4.86963481e-01 5.04682027e-01 8.63815335e-01
#  4.06976097e-02 3.49974740e-01 8.09526504e-02 1.36767988e-01
#  2.06939988e-01 2.93132364e-01 3.89259491e-01 4.15100552e-01
#  3.46681491e-01 3.87658898e-02 4.06900806e-01 1.25408533e-02
#  2.65371263e-01 1.05038761e+00 1.36730283e-01 4.08680123e-02
#  7.02612580e-01 2.56289718e-01 8.11605998e-02 2.40044311e-01
#  8.66314581e-01 2.26092327e-01 4.62551185e-01 2.33341401e-02
#  7.44946044e-02 4.45865243e-01 2.67085785e-01 5.79428586e-01
#  1.05433352e-01 8.88503191e-02 5.65617333e-04 4.25106550e-02
#  2.99442248e-01 5.88192834e-03 1.43526230e-01 1.10426837e-01
#  3.43822442e-01 2.44689401e-01 1.58536159e-01 3.64553292e-01
#  3.99538835e-01 5.02317583e-01 1.15457238e-02 8.50667576e-02
#  7.76322516e-02 6.71824429e-02 2.29986437e-01 5.36983051e-02
#  1.36527222e-02 4.45446883e-01 4.17863062e-02 2.29944162e-02
#  1.92820573e-03 2.28780035e-01 2.36215420e-01 4.77847481e-01
#  6.96395623e-02 3.06625805e-01 1.90819171e-01 2.65908033e-02
#  2.20593874e-01 4.08912464e-01 7.33384878e-01 2.60321608e-01
#  6.99177673e-02 1.94214386e-01 1.58871036e-01 6.19192127e-01
#  1.60768841e-01 7.03663511e-02 2.03159604e-01 5.25922478e-01
#  6.86937638e-02 4.37815871e-04 4.72038382e-01 3.12104871e-01
#  5.39055135e-02 4.24955099e-01 6.48451154e-02 1.99758171e-01]

# %%
ebins = np.linspace(0,5,100)
xcq = (ebins[:-1] + ebins[1:]) / 2
n,nx = np.histogram(a,bins=ebins)

#nel,nxel = np.histogram(a,bins=ebins)

# %%
#set up a 1d plot
fig,axes = plt.subplots(1,1,figsize=(15.0,8.0),sharex=True)
ax1 = axes


#thist = n/np.sum(n)/np.diff(xcq*1000)[0]


#print(estring)
ax1.step(xcq,n, where='mid',color='m', linestyle='-', \
            label='Exponential', linewidth=2)


ymin = 0
ymax = 200

blue = '#118DFA'
ax1.fill_between(xcq,np.zeros(np.shape(xcq)),n,step='mid',facecolor='b',alpha=0.4, \
                 label='')


#ax1.set_yscale('linear')
ax1.set_yscale('linear')
ax1.set_xlim(0.0, 5) 
ax1.set_ylim(ymin,ymax)
ax1.set_xlabel(r'value')
ax1.set_ylabel('counts')
ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
ax1.legend(loc=1,prop={'size':22})
#ax1.legend(bbox_to_anchor=(1.04,1),borderaxespad=0,prop={'size':22})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
#plt.savefig('paper_figures/hist.eps')
plt.savefig('hist.pdf')
plt.show()

# %%
#Find elastic cross sections
sc=4.95e-24 #Elastic cross section of Carbon 12 at 10keV in cm^2
rhoc=2.26 #in g/cm^3
mc=1.99269e-23 #in g
nc=rhoc/mc
sigmac=nc*sc
print(sigmac)

sh=3.027e-23 #Elastic cross section of Hydrogen 1 at 10keV in cm^2
rhoh=0.0000899 #in g/cm^3
mh=1.67e-24 #in g
nh=rhoh/mh
sigmah=nh*sh
print(sigmah)

su=9.24e-24 #Elastic cross section of Uranium 238 at 10keV in cm^2
rhou=19.05 #in g/cm^3
mu=3.9521e-22 #in g
nu=rhou/mu
sigmau=nu*su
print(sigmau)

sl=s #Elastic cross section of Uranium 238 at 10keV in cm^2
rhol=rho #in g/cm^3
ml=m #in g
nl=rhol/ml
sigmal=nl*sl
print(sigmal)
# Out:
# 0.5614019240323381
# 0.0016295047904191617
# 0.4453885276182283
# 0.2701463245892188

# %%
#Number lists
ac = np.random.exponential(scale=sigmac, size=10000)
ah = np.random.exponential(scale=sigmah, size=10000)
au = np.random.exponential(scale=sigmau, size=10000)
al = np.random.exponential(scale=sigmal, size=10000)

# %%
#histograms
ebinsnew = np.linspace(0,0.1,100)
#set bins as 0-0.1 to zoom in on Hydrogen plot
xcqnew = (ebinsnew[:-1] + ebins[1:]) / 2


nc,nx = np.histogram(ac,bins=ebinsnew)
nh,nx = np.histogram(ah,bins=ebinsnew)
nu,nx = np.histogram(au,bins=ebinsnew)
nl,nx = np.histogram(al,bins=ebinsnew)

# %%
#set up a 1d plot
fig,axes = plt.subplots(1,1,figsize=(15.0,8.0),sharex=True)
ax1 = axes


#thist = n/np.sum(n)/np.diff(xcq*1000)[0]


#print(estring)
ax1.step(xcqnew,nl, where='mid',color='m', linestyle='-', \
            label='Lead209', linewidth=2)
ax1.step(xcqnew,nc, where='mid',color='k', linestyle='-', \
            label='Carbon12', linewidth=2)
ax1.step(xcqnew,nh, where='mid',color='r', linestyle='-', \
            label='Hydrogen1', linewidth=2)
ax1.step(xcqnew,nu, where='mid',color='b', linestyle='-', \
            label='Uranium238', linewidth=2)

ymin = 0
ymax = 5000


#ax1.set_yscale('linear')
ax1.set_yscale('linear')
ax1.set_xlim(0.0, 5)
#changed xlim away from 5 to set scale for H-1
ax1.set_ylim(ymin,ymax)
ax1.set_xlabel(r'value')
ax1.set_ylabel('counts')
ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
ax1.legend(loc=1,prop={'size':22})
#ax1.legend(bbox_to_anchor=(1.04,1),borderaxespad=0,prop={'size':22})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
#plt.savefig('paper_figures/hist.eps')
#plt.savefig('hist.pdf')
plt.show()

# %%
#Generate list and distribution for each element in concrete. Graph these and mark the element with lowest average distance until collisison as minimum.
#Did these by hand, practice by also doing code for them
#Elastic macroscopic cross sections
sigma1=0.416
sigma6=0.000571
sigma8=0.1826
sigma11=0.00323
sigma12=0.000436
sigma13=0.00251
sigma14=0.0331
sigma19=0.000961
sigma20=0.00466
sigma26=0.0042

# %%
#Number lists
a1 = np.random.exponential(scale=sigma1, size=10000)
a6 = np.random.exponential(scale=sigma6, size=10000)
a8 = np.random.exponential(scale=sigma8, size=10000)
a11 = np.random.exponential(scale=sigma11, size=10000)
a12 = np.random.exponential(scale=sigma12, size=10000)
a13 = np.random.exponential(scale=sigma13, size=10000)
a14 = np.random.exponential(scale=sigma14, size=10000)
a19 = np.random.exponential(scale=sigma19, size=10000)
a20 = np.random.exponential(scale=sigma20, size=10000)
a26 = np.random.exponential(scale=sigma26, size=10000)

# %%
#histograms
ebinsc = np.linspace(0,1,100)
xcqc = (ebinsc[:-1] + ebins[1:]) / 2

n1,nx = np.histogram(a1,bins=ebinsc)
n6,nx = np.histogram(a6,bins=ebinsc)
n8,nx = np.histogram(a8,bins=ebinsc)
n11,nx = np.histogram(a11,bins=ebinsc)
n12,nx = np.histogram(a12,bins=ebinsc)
n13,nx = np.histogram(a13,bins=ebinsc)
n14,nx = np.histogram(a14,bins=ebinsc)
n19,nx = np.histogram(a19,bins=ebinsc)
n20,nx = np.histogram(a20,bins=ebinsc)
n26,nx = np.histogram(a26,bins=ebinsc)

# %%
#Plot
fig,axes = plt.subplots(1,1,figsize=(15.0,8.0),sharex=True)
ax1 = axes

ax1.step(xcqc,n1, where='mid',color='r', linestyle='-', \
            label='1', linewidth=2)
ax1.step(xcqc,n6, where='mid',color='g', linestyle='-', \
            label='6', linewidth=2)
ax1.step(xcqc,n8, where='mid',color='b', linestyle='-', \
            label='8', linewidth=2)
ax1.step(xcqc,n11, where='mid',color='r', linestyle='-', \
            label='11', linewidth=2)
ax1.step(xcqc,n12, where='mid',color='g', linestyle='-', \
            label='12', linewidth=2)
ax1.step(xcqc,n13, where='mid',color='b', linestyle='-', \
            label='13', linewidth=2)
ax1.step(xcqc,n14, where='mid',color='r', linestyle='-', \
            label='14', linewidth=2)
ax1.step(xcqc,n19, where='mid',color='g', linestyle='-', \
            label='19', linewidth=2)
ax1.step(xcqc,n20, where='mid',color='b', linestyle='-', \
            label='20', linewidth=2)
ax1.step(xcqc,n26, where='mid',color='r', linestyle='-', \
            label='26', linewidth=2)
ymin = 0
ymax = 5000

ax1.set_yscale('linear')
ax1.set_xlim(0.0, 5)
ax1.set_ylim(ymin,ymax)
ax1.set_xlabel(r'value')
ax1.set_ylabel('counts')
ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
ax1.legend(loc=1,prop={'size':22})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
plt.show()
