# %%
#we may need some code in the ../python directory and/or matplotlib styles
import sys
sys.path.append('../python/')

#matplotlib for plotting
import matplotlib as mpl
from matplotlib import pyplot as plt
plt.style.use('../mplstyles/stylelib/standard.mplstyle')

import numpy as np

# %%
a = np.random.exponential(scale=1.0, size=100)
print(a)
# Out:
# [6.73369897e-01 2.16472895e-01 3.52674532e-01 1.22043608e-01
#  4.28906863e-01 4.57936638e+00 6.55797190e-01 8.05948698e-02
#  2.59813563e+00 3.96502554e+00 1.53036831e+00 2.51511903e-01
#  1.10045192e+00 1.22909238e-01 5.99408360e-02 9.16920251e-02
#  3.21462641e-02 8.95918740e-03 8.54788036e-02 9.49457103e-01
#  1.95237586e+00 2.00435274e+00 2.59347301e-02 1.07205783e+00
#  6.29122057e-01 1.80952750e+00 5.60330149e-02 1.52402556e+00
#  4.93674408e-01 1.05975608e+00 5.65663954e-02 3.23124804e+00
#  4.79151140e-01 8.29548031e-01 5.45502577e-01 3.35302813e-01
#  2.00753754e+00 1.11895616e+00 5.31451403e-01 1.39241005e-01
#  7.09684485e-01 7.36575049e-01 6.00735941e-02 5.81266517e-01
#  3.10275184e-02 2.69160099e+00 4.94805121e-01 7.70772631e-01
#  1.86956965e+00 9.89150042e-01 4.94091817e-03 7.87247586e-01
#  2.07204407e+00 4.78927134e+00 4.08756205e-01 2.38902600e+00
#  9.18424071e-01 1.04522229e+00 7.32599731e-01 1.12459058e+00
#  6.52438025e-02 2.88909888e-03 1.04069608e+00 2.87837224e+00
#  2.10070731e-01 2.57797907e-01 5.64826197e-01 3.65004150e-01
#  4.65037843e-01 1.91628735e+00 9.90055154e-01 9.74385092e-01
#  1.87775808e-01 3.38488866e-01 2.00964905e-01 1.17391581e+00
#  1.09457654e+00 1.34584315e+00 1.73490890e+00 1.25622470e+00
#  1.65000063e+00 1.35953532e+00 2.74512722e-01 1.51032968e+00
#  4.49663478e+00 3.33315570e-01 3.50612455e-01 1.61759206e+00
#  4.96998150e-01 8.43258611e-01 1.27441406e+00 8.16472797e-01
#  1.02069852e+00 9.23156154e-01 3.09638322e-02 2.40288944e-01
#  2.09828545e-01 1.06482269e-01 1.42497651e-01 6.84488970e-01]

# %%
ebins = np.linspace(0,5,100)
xcq = (ebins[:-1] + ebins[1:]) / 2
n,nx = np.histogram(a,bins=ebins)

nel,nxel = np.histogram(a,bins=ebins)

# %%
#set up a 1d plot
fig,axes = plt.subplots(1,1,figsize=(15.0,8.0),sharex=True)
ax1 = axes


thist = n/np.sum(n)/np.diff(xcq*1000)[0]


#print(estring)
ax1.step(xcq,nel, where='mid',color='m', linestyle='-', \
            label='Exponential', linewidth=2)


ymin = 0
ymax = 10

blue = '#118DFA'
ax1.fill_between(xcq,np.zeros(np.shape(xcq)),nel,step='mid',facecolor='b',alpha=0.4, \
                 label='')


#ax1.set_yscale('linear')
ax1.set_yscale('linear')
ax1.set_xlim(0.0, 5) 
ax1.set_ylim(ymin,ymax)
ax1.set_xlabel(r'value')
ax1.set_ylabel('counts')
ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
ax1.legend(loc=1,prop={'size':22})
#ax1.legend(bbox_to_anchor=(1.04,1),borderaxespad=0,prop={'size':22})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
#plt.savefig('paper_figures/hist.eps')
#plt.savefig('paper_figures/hist.pdf')
plt.show()
